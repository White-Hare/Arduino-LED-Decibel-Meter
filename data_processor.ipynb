# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./mmc1.xls', header=1)

# %%
timeColumn = df.iloc[:, 0].head(100)
decibalColumn = df.iloc[:, 2].head(100)

# %%
plt.plot(timeColumn, decibalColumn)

# %%
np.median(decibalColumn)
# Out:
# 72.1
